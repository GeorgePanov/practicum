# %% [markdown]
# <font color='black' size=6><b>Исследование надёжности заёмщиков</b></font>
#
# Заказчик — кредитный отдел банка. Нужно разобраться, влияет ли семейное положение и количество детей клиента на факт погашения кредита в срок. Входные данные от банка — статистика о платёжеспособности клиентов.
#
# Результаты исследования будут учтены при построении модели **кредитного скоринга** — специальной системы, которая оценивает способность потенциального заёмщика вернуть кредит банку.

# %% [markdown]
# # Откройте файл с данными и изучите общую информацию

# %%
import pandas as pd
from pymystem3 import Mystem
m = Mystem()

# %%
data = pd.read_csv('C:/Users/George/Мой диск/Практикум/Проекты/GitHub/2 Предобработка данных/data.csv')
display(data.head(10))
print(data.info())
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1   -8437.673028         42    высшее             0
# 1         1   -4024.803754         36   среднее             1
# 2         0   -5623.422610         33   Среднее             1
# 3         3   -4124.747207         32   среднее             1
# 4         0  340266.072047         53   среднее             1
# 5         0    -926.185831         27    высшее             0
# 6         0   -2879.202052         43    высшее             0
# 7         0    -152.779569         50   СРЕДНЕЕ             1
# 8         2   -6929.865299         35    ВЫСШЕЕ             0
# 9         0   -2188.756445         41   среднее             1
#
#       family_status  family_status_id gender income_type  debt   total_income  \
# 0   женат / замужем                 0      F   сотрудник     0  253875.639453
# 1   женат / замужем                 0      F   сотрудник     0  112080.014102
# 2   женат / замужем                 0      M   сотрудник     0  145885.952297
# 3   женат / замужем                 0      M   сотрудник     0  267628.550329
# 4  гражданский брак                 1      F   пенсионер     0  158616.077870
# 5  гражданский брак                 1      M   компаньон     0  255763.565419
# 6   женат / замужем                 0      F   компаньон     0  240525.971920
# 7   женат / замужем                 0      M   сотрудник     0  135823.934197
# 8  гражданский брак                 1      F   сотрудник     0   95856.832424
# 9   женат / замужем                 0      M   сотрудник     0  144425.938277
#
#                       purpose
# 0               покупка жилья
# 1     приобретение автомобиля
# 2               покупка жилья
# 3  дополнительное образование
# 4             сыграть свадьбу
# 5               покупка жилья
# 6           операции с жильем
# 7                 образование
# 8       на проведение свадьбы
# 9     покупка жилья для семьи
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
# children            21525 non-null int64
# days_employed       19351 non-null float64
# dob_years           21525 non-null int64
# education           21525 non-null object
# education_id        21525 non-null int64
# family_status       21525 non-null object
# family_status_id    21525 non-null int64
# gender              21525 non-null object
# income_type         21525 non-null object
# debt                21525 non-null int64
# total_income        19351 non-null float64
# purpose             21525 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB
# None

# %% [markdown]
# **Вывод**

# %% [markdown]
# Видно, что пропущенные значения только в столбцах "days_employed" и "total_income".
# Но еще мне не понятно, почему рабочий стаж ("days_employed") имеет отрицательные значения.

# %% [markdown]
# # Предобработка данных

# %% [markdown]
# ## Обработка пропусков

# %%
# переводим все отрицательные значения в положительные
data['days_employed'] = abs(data['days_employed'])

# выявляем медиану для рабочих дней и подставляем в пропущенные значения
median_days = data['days_employed'].median()
data['days_employed'] = data['days_employed'].fillna(median_days)

# выявляем медиану для ежемесячного дохода и подставляем в пропущенные значения
median_income = data['total_income'].median()
data['total_income'] = data['total_income'].fillna(median_income)

data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
# children            21525 non-null int64
# days_employed       21525 non-null float64
# dob_years           21525 non-null int64
# education           21525 non-null object
# education_id        21525 non-null int64
# family_status       21525 non-null object
# family_status_id    21525 non-null int64
# gender              21525 non-null object
# income_type         21525 non-null object
# debt                21525 non-null int64
# total_income        21525 non-null float64
# purpose             21525 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB
#    children  days_employed  dob_years education  education_id  \
# 0         1    8437.673028         42    высшее             0
# 1         1    4024.803754         36   среднее             1
# 2         0    5623.422610         33   Среднее             1
# 3         3    4124.747207         32   среднее             1
# 4         0  340266.072047         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt   total_income  \
# 0   женат / замужем                 0      F   сотрудник     0  253875.639453
# 1   женат / замужем                 0      F   сотрудник     0  112080.014102
# 2   женат / замужем                 0      M   сотрудник     0  145885.952297
# 3   женат / замужем                 0      M   сотрудник     0  267628.550329
# 4  гражданский брак                 1      F   пенсионер     0  158616.077870
#
#                       purpose
# 0               покупка жилья
# 1     приобретение автомобиля
# 2               покупка жилья
# 3  дополнительное образование
# 4             сыграть свадьбу

# %% [markdown]
# **Вывод**

# %% [markdown]
# Отрицательные значения я перевел в положительные (потому что не может быть отрицательного опыта в дня).<br>
# Заменил пропуски в столбцах "days_employed" и "total_income" на медианы этих столбцов.

# %% [markdown]
# ## Замена типа данных

# %%
def f_to_int(value):
    integer = int(value)
    return integer

data['days_employed'] = data['days_employed'].apply(f_to_int)
data['total_income'] = data['total_income'].apply(f_to_int)

data.head()
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1           8437         42    высшее             0
# 1         1           4024         36   среднее             1
# 2         0           5623         33   Среднее             1
# 3         3           4124         32   среднее             1
# 4         0         340266         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt  total_income  \
# 0   женат / замужем                 0      F   сотрудник     0        253875
# 1   женат / замужем                 0      F   сотрудник     0        112080
# 2   женат / замужем                 0      M   сотрудник     0        145885
# 3   женат / замужем                 0      M   сотрудник     0        267628
# 4  гражданский брак                 1      F   пенсионер     0        158616
#
#                       purpose
# 0               покупка жилья
# 1     приобретение автомобиля
# 2               покупка жилья
# 3  дополнительное образование
# 4             сыграть свадьбу

# %% [markdown]
# Или так:
#
#     data['days_employed'] = data['days_employed'].astype('Int64')

# %% [markdown]
# **Вывод**

# %% [markdown]
# Вещественные значения столбцов "days_employed" и "total_income" заменил на целочисленные

# %% [markdown]
# ## Обработка дубликатов

# %%
# data.duplicated().sum()
# было показано 54

data['education'] = data['education'].str.lower()

# data.duplicated().sum()
# было показано 71

data = data.drop_duplicates().reset_index(drop=True)
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Вывод**

# %% [markdown]
# Я заметил одинаковые значения в столбце "education" написанные в разном регистре, поэтому я решил их привести к одному регистру. Таким образом колличество дубликатов оказалось не 54, а 71. Методом "drop_duplicates().reset_index(drop=True)" я их удалил.
#
# Дубликаты разные, потому что люди по-разному записали своё образование. Не думаю, что в анкете было написано "только строчными буквами" или на оборот заглавными.

# %% [markdown]
# ## Лемматизация

# %%
# смотрим какие значения есть в столбце "purpose"
# data['purpose'].unique()

# создаём функцию которая определяет к какой группе относится заем
def create_category_purpose(data):
    lem_purpose = m.lemmatize(data['purpose'])
    if 'автомобиль' in lem_purpose:
        return 'автомобиль'
    elif ('жилье' in lem_purpose) or ('недвижимость' in lem_purpose ):
        return 'недвижимость'
    elif 'образование' in lem_purpose:
        return 'образование'
    elif 'свадьба' in lem_purpose:
        return 'свадьба'
    else:
        return 'other'

data['purpose_category'] = data.apply(create_category_purpose, axis=1)
data.groupby('purpose_category')['purpose_category'].count()

# %% [markdown]
# **Вывод**

# %% [markdown]
# Можно заметь, что на покупку недвижимости люди берут кредит больше всего, а на свадьбу - меньше всего.
# На образование и автомобиль берут примерно одинаковое колличество людей.

# %% [markdown]
# ## Категоризация данных

# %%
# data['children'].unique()
# array([ 1,  0,  3,  2, -1,  4, 20,  5])
# Мы видим, что в таблице есть минусовое значение. Наверно это опечатка.

# print(data[data['children'] == -1]['children'].count())
# 47 отрицательных значений. Думаю, что это опечатка. Надо сделать их положительными.

data['children'] = abs(data['children'])
# data['children'].unique()
# array([ 1,  0,  3,  2,  4, 20,  5])



# теперь сделаем столбец с наличием детей (Есть/Нет)
def Are_there_children(table):
    if table['children'] > 0:
        return 'Есть дети'
    else:
        return 'Нет детей'

# сделаем столбец с задолжностями (Были/Нет)
def Are_there_debt(table):
    if table['debt'] > 0:
        return 'Были задолжности'
    else:
        return 'Не было задолжностей'

# сделаем столбец с уровнем дохода
def income_level(table):
    if table['total_income'] <= 75000:
        return 'Низкий доход'
    elif 75000 < table['total_income'] <= 200000:
        return 'Средний доход'
    elif 200000 < table['total_income'] <= 500000:
        return 'Высокий доход'
    elif 500000 < table['total_income']:
        return 'Богач'
   
    
    
data['income_level'] = data.apply(income_level, axis=1)
data['have_children'] = data.apply(Are_there_children, axis=1)
data['have_debt'] = data.apply(Are_there_debt, axis=1)

data.head()
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1           8437         42    высшее             0
# 1         1           4024         36   среднее             1
# 2         0           5623         33   среднее             1
# 3         3           4124         32   среднее             1
# 4         0         340266         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt  total_income  \
# 0   женат / замужем                 0      F   сотрудник     0        253875
# 1   женат / замужем                 0      F   сотрудник     0        112080
# 2   женат / замужем                 0      M   сотрудник     0        145885
# 3   женат / замужем                 0      M   сотрудник     0        267628
# 4  гражданский брак                 1      F   пенсионер     0        158616
#
#                       purpose   income_level have_children  \
# 0               покупка жилья  Высокий доход     Есть дети
# 1     приобретение автомобиля  Средний доход     Есть дети
# 2               покупка жилья  Средний доход     Нет детей
# 3  дополнительное образование  Высокий доход     Есть дети
# 4             сыграть свадьбу  Средний доход     Нет детей
#
#               have_debt
# 0  Не было задолжностей
# 1  Не было задолжностей
# 2  Не было задолжностей
# 3  Не было задолжностей
# 4  Не было задолжностей

# %%
data.groupby('income_level')['income_level'].count()
# Out:
# income_level
# Богач              222
# Высокий доход     4844
# Низкий доход      1865
# Средний доход    14523
# Name: income_level, dtype: int64

# %% [markdown]
# **Вывод**

# %% [markdown]
# Большинство людей, которые берут кредит находятся в среднем классе.

# %% [markdown]
# # Ответьте на вопросы

# %% [markdown]
# ## Есть ли зависимость между наличием детей и возвратом кредита в срок?

# %%
data_pivot = data.pivot_table(
    index='have_children', 
    columns=['have_debt'], 
    values='debt', 
    aggfunc='count')

data_pivot['Percentage_of_return'] = 100 - data_pivot['Были задолжности'] / data_pivot['Не было задолжностей'] * 100

display(data_pivot.sort_values(by='Percentage_of_return', ascending=False))
# Out:
# have_debt      Были задолжности  Не было задолжностей  Percentage_of_return
# have_children
# Нет детей                  1063                 13028             91.840651
# Есть дети                   678                  6685             89.857891

# %% [markdown]
# **Вывод** <br>
# Таблица показывает: что те, у кого нет детей чаще возвращают кредит в срок, чем те, у кого есть.

# %% [markdown]
# ## Есть ли зависимость между семейным положением и возвратом кредита в срок?

# %%
data_pivot = data.pivot_table(
    index='family_status', 
    columns=['have_debt'], 
    values='debt', 
    aggfunc='count')

# создаём дополнительную таблицу отношений между столбцами
data_pivot['Percentage_of_return'] = 100 - data_pivot['Были задолжности'] / data_pivot['Не было задолжностей'] * 100


display(data_pivot.sort_values(by='Percentage_of_return',ascending=False))
# Out:
# have_debt              Были задолжности  Не было задолжностей  \
# family_status
# вдовец / вдова                       63                   896
# в разводе                            85                  1110
# женат / замужем                     931                 11408
# гражданский брак                    388                  3763
# Не женат / не замужем               274                  2536
#
# have_debt              Percentage_of_return
# family_status
# вдовец / вдова                    92.968750
# в разводе                         92.342342
# женат / замужем                   91.839060
# гражданский брак                  89.689078
# Не женат / не замужем             89.195584

# %% [markdown]
# **Вывод** <br>
# *Проанализировав таблицу можно сделать выводы:*
#  - Люди, находящиеся не в браке, отдают кредит вовремя реже, чем все остальные. На предпоследнем месте находятся люди, состоящие в гражданском браке.
#  - А овдовевшие граждане чаще остальных отдают кредит во время.

# %% [markdown]
# ## Есть ли зависимость между уровнем дохода и возвратом кредита в срок?

# %%
data_pivot = data.pivot_table(
    index='income_level', 
    columns=['have_debt'], 
    values='debt', 
    aggfunc='count')

# создаём дополнительную таблицу отношений между столбцами
data_pivot['Percentage_of_return'] = 100 - data_pivot['Были задолжности'] / data_pivot['Не было задолжностей'] * 100

display(data_pivot.sort_values(by='Percentage_of_return',ascending=False))
# Out:
# have_debt      Были задолжности  Не было задолжностей  Percentage_of_return
# income_level
# Богач                        14                   208             93.269231
# Высокий доход               344                  4500             92.355556
# Низкий доход                136                  1729             92.134182
# Средний доход              1247                 13276             90.607111

# %% [markdown]
# **Вывод** <br>
# Видно, что богатые люди отдают кредит во время чаще остальных. А хуже всех отдают люди с средним доходом

# %% [markdown]
# ## Как разные цели кредита влияют на его возврат в срок?

# %%
data
# Out:
#        children  days_employed  dob_years education  education_id  \
# 0             1           8437         42    высшее             0
# 1             1           4024         36   среднее             1
# 2             0           5623         33   среднее             1
# 3             3           4124         32   среднее             1
# 4             0         340266         53   среднее             1
# ...         ...            ...        ...       ...           ...
# 21449         1           4529         43   среднее             1
# 21450         0         343937         67   среднее             1
# 21451         1           2113         38   среднее             1
# 21452         3           3112         38   среднее             1
# 21453         2           1984         40   среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 0       женат / замужем                 0      F   сотрудник     0
# 1       женат / замужем                 0      F   сотрудник     0
# 2       женат / замужем                 0      M   сотрудник     0
# 3       женат / замужем                 0      M   сотрудник     0
# 4      гражданский брак                 1      F   пенсионер     0
# ...                 ...               ...    ...         ...   ...
# 21449  гражданский брак                 1      F   компаньон     0
# 21450   женат / замужем                 0      F   пенсионер     0
# 21451  гражданский брак                 1      M   сотрудник     1
# 21452   женат / замужем                 0      M   сотрудник     1
# 21453   женат / замужем                 0      F   сотрудник     0
#
#        total_income                       purpose   income_level  \
# 0            253875                 покупка жилья  Высокий доход
# 1            112080       приобретение автомобиля  Средний доход
# 2            145885                 покупка жилья  Средний доход
# 3            267628    дополнительное образование  Высокий доход
# 4            158616               сыграть свадьбу  Средний доход
# ...             ...                           ...            ...
# 21449        224791             операции с жильем  Высокий доход
# 21450        155999          сделка с автомобилем  Средний доход
# 21451         89672                  недвижимость  Средний доход
# 21452        244093  на покупку своего автомобиля  Высокий доход
# 21453         82047         на покупку автомобиля  Средний доход
#
#       have_children             have_debt
# 0         Есть дети  Не было задолжностей
# 1         Есть дети  Не было задолжностей
# 2         Нет детей  Не было задолжностей
# 3         Есть дети  Не было задолжностей
# 4         Нет детей  Не было задолжностей
# ...             ...                   ...
# 21449     Есть дети  Не было задолжностей
# 21450     Нет детей  Не было задолжностей
# 21451     Есть дети      Были задолжности
# 21452     Есть дети      Были задолжности
# 21453     Есть дети  Не было задолжностей
#
# [21454 rows x 15 columns]

# %%
data_pivot = data.pivot_table(
    index='purpose_category', 
    columns=['have_debt'], 
    values='debt', 
    aggfunc='count')

data_pivot['Percentage_of_return'] = 100 - data_pivot['Были задолжности'] / data_pivot['Не было задолжностей'] * 100

display(data_pivot.sort_values(by='Percentage_of_return',ascending=False))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1616\1885322280.py in <module>
#       3     columns=['have_debt'],
#       4     values='debt',
# ----> 5     aggfunc='count')
#       6
#       7 data_pivot['Percentage_of_return'] = 100 - data_pivot['Были задолжности'] / data_pivot['Не было задолжностей'] * 100
#
# ~\.conda\envs\praktikum_env_win_new\lib\site-packages\pandas\core\frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#    6072             dropna=dropna,
#    6073             margins_name=margins_name,
# -> 6074             observed=observed,
#    6075         )
#    6076
#
# ~\.conda\envs\praktikum_env_win_new\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      93         values = list(values)
#      94
# ---> 95     grouped = data.groupby(keys, observed=observed)
#      96     agged = grouped.agg(aggfunc)
#      97     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#
# ~\.conda\envs\praktikum_env_win_new\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7892             squeeze=squeeze,
#    7893             observed=observed,
# -> 7894             **kwargs
#    7895         )
#    7896
#
# ~\.conda\envs\praktikum_env_win_new\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2520         raise TypeError("invalid type: {}".format(obj))
#    2521
# -> 2522     return klass(obj, by, **kwds)
#
# ~\.conda\envs\praktikum_env_win_new\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     389                 sort=sort,
#     390                 observed=observed,
# --> 391                 mutated=self.mutated,
#     392             )
#     393
#
# ~\.conda\envs\praktikum_env_win_new\lib\site-packages\pandas\core\groupby\grouper.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     619                 in_axis, name, level, gpr = False, None, gpr, None
#     620             else:
# --> 621                 raise KeyError(gpr)
#     622         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     623             # Add key to exclusions
#
# KeyError: 'purpose_category'

# %% [markdown]
# **Вывод** <br>
# Кредиты на недвижимость возвращают во время, а кредиты на автомобиль реже других.

# %% [markdown]
# # Общий вывод

# %% [markdown]
# Резюмирую <br>
# Вопрос изначально был поставлен такой: "Влияет ли семейное положение и количество детей клиента на факт погашения кредита в срок".<br>
# Про анализировав таблицу можно сделать такие выводы:
#  - Семейное положение влияет на факт погашения кредита в срок: Люди находящиеся НЕ в браке реже остальных возвращают кредит в срок, что удивительно. Люди, находящиеся в браке возвращают кредит не чаще и не реже других. А вот как оказалось оводовевшие граждане чаще всех остальных погашают кредит в срок.
#  - Наличие детей также влияет на факт погашения кредита в срок: Клиенты у которых есть дети реже возвращают кредит в срок.
